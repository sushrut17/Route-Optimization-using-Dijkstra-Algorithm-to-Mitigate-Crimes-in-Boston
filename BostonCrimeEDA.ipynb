# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import imageio

import folium
import folium.plugins
from folium.plugins import MarkerCluster
from ipywidgets import interactive


from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn.metrics import log_loss
from sklearn.metrics import make_scorer
from sklearn.model_selection import StratifiedShuffleSplit
from matplotlib.colors import LogNorm
from sklearn.decomposition import PCA
from keras.layers.advanced_activations import PReLU
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.utils import np_utils
from copy import deepcopy
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
crime = pd.read_csv('/Users/jenniferwu/Desktop/MSBA/Fall 2019/Data Analytics/crimes-in-boston/crimetodate.csv'
                    ,encoding = 'latin')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435655 entries, 0 to 435654
# Data columns (total 17 columns):
# INCIDENT_NUMBER        435655 non-null object
# OFFENSE_CODE           435655 non-null int64
# OFFENSE_CODE_GROUP     426840 non-null object
# OFFENSE_DESCRIPTION    435655 non-null object
# DISTRICT               433439 non-null object
# REPORTING_AREA         435655 non-null object
# SHOOTING               10562 non-null object
# OCCURRED_ON_DATE       435655 non-null object
# YEAR                   435655 non-null int64
# MONTH                  435655 non-null int64
# DAY_OF_WEEK            435655 non-null object
# HOUR                   435655 non-null int64
# UCR_PART               426730 non-null object
# STREET                 422330 non-null object
# Lat                    399636 non-null float64
# Long                   399636 non-null float64
# Location               435655 non-null object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 56.5+ MB

# %%
crime['Location_lat']= [i.split(', ')[0].split('(')[1] for i in crime.Location]
crime['Location_long']= [i.split(', ')[1].split(')')[0] for i in crime.Location]

crime['Location_lat']=crime.Location_lat.astype('float64')
crime['Location_long']=crime.Location_long.astype('float64')

# %%
crime.drop('Location', axis = 1, inplace = True)

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435655 entries, 0 to 435654
# Data columns (total 18 columns):
# INCIDENT_NUMBER        435655 non-null object
# OFFENSE_CODE           435655 non-null int64
# OFFENSE_CODE_GROUP     426840 non-null object
# OFFENSE_DESCRIPTION    435655 non-null object
# DISTRICT               433439 non-null object
# REPORTING_AREA         435655 non-null object
# SHOOTING               10562 non-null object
# OCCURRED_ON_DATE       435655 non-null object
# YEAR                   435655 non-null int64
# MONTH                  435655 non-null int64
# DAY_OF_WEEK            435655 non-null object
# HOUR                   435655 non-null int64
# UCR_PART               426730 non-null object
# STREET                 422330 non-null object
# Lat                    399636 non-null float64
# Long                   399636 non-null float64
# Location_lat           435655 non-null float64
# Location_long          435655 non-null float64
# ...

# %%
#changing the datatype to date time and creating a separate column just for the date occured

crime['date_occured']=[i.split(' ')[0] for i in crime.OCCURRED_ON_DATE]
crime['occured_on_dttm'] = pd.to_datetime(crime.OCCURRED_ON_DATE)

# %%
#dropping the original date column
crime.drop(columns = 'OCCURRED_ON_DATE', inplace = True)

# %%
#replace Values in Shooting variable into 0,1
crime['SHOOTING'] = crime['SHOOTING'].replace(to_replace = np.nan, value =0) 
crime['SHOOTING'] = crime['SHOOTING'].replace(to_replace = 'Y', value=1)

# %% [markdown]
# Removing Null , NAN, and Wrong Coordinates Lat & Long for Final Cleaned Data used for EDA

# %%
crime = crime[(crime.Lat.notnull()) & (crime.Location_lat != 0)]

# %%
crime = crime[(crime.Lat != -1) & (crime.Long != -1)]

# %%
crime = crime[~crime.Lat.isna()]

# %%
#crime.to_csv('/Users/jenniferwu/Documents/BostonCrimeProject/crimes-in-boston/crimetodate_cleaneddata.csv')

# %%
sns.countplot("YEAR", data = crime)
print("min data date :", min(crime.occured_on_dttm))
print("max data date :", max(crime.occured_on_dttm))
print("Incomplete year data on 2015 & 2019")
# Out:
# min data date : 2015-06-15 00:00:00
# max data date : 2019-10-13 09:28:24
# Incomplete year data on 2015 & 2019

# %%
#plotting Crime Distribution by Day of Week and Comparing the years
#result = Pretty Flat :(
sns.set_palette("pastel")
def week(Year):
    return sns.countplot("DAY_OF_WEEK",order=crime.DAY_OF_WEEK.value_counts().index, data = crime[crime.YEAR == Year])
interactive(week,Year=(2015,2019,1))
# Out:
# interactive(children=(IntSlider(value=2017, description='Year', max=2019, min=2015), Output()), _dom_classes=(…

# %%
#plotting Crime Distribution by hour
#result = starts from 7AM & Peaks in the Afternoon (4pm to 7pm) -- this is true across all 4 years

#2k15
def hour(Year):
    return sns.countplot("HOUR", data =  crime[crime.YEAR == Year])
interactive(hour,Year=(2015,2019,1))
# Out:
# interactive(children=(IntSlider(value=2017, description='Year', max=2019, min=2015), Output()), _dom_classes=(…

# %%
##Offense Group During Peak Time (4pm to 7 pm, 11pm to 12am)
hr = crime[(crime.HOUR >= 16) & (crime.HOUR <=19) | (crime.HOUR >= 23) &(crime.HOUR <=0)]

sns.catplot(y='OFFENSE_CODE_GROUP',
           kind='count',
            height=8, 
            aspect=1.5,
            order=hr.OFFENSE_CODE_GROUP.value_counts().head(12).index,
           data=hr)
plt.title("Top 70% Crime Type During High Crime Hour in Boston from 2015 to 2019", size = 20)
# Out:
# Text(0.5, 1, 'Top 70% Crime Type During High Crime Hour in Boston from 2015 to 2019')

# %%
sns.catplot(y='OFFENSE_CODE_GROUP',
           kind='count',
            height=8, 
            aspect=1.5,
            order=crime.OFFENSE_CODE_GROUP.value_counts().head(12).index,
           data=crime)
plt.title("Top 70% Crime Type in Boston from 2015 to 2019", size = 20)
# Out:
# Text(0.5, 1, 'Top 70% Crime Type in Boston from 2015 to 2019')

# %%
cmp_cat = cmp.groupby(['OFFENSE_CODE_GROUP']).agg({"name":"count"})
cmp_cat = cmp_cat.sort_values(by='name',ascending=False)
cmp_cat["cumpercentage"] = cmp_cat["name"].cumsum()/cmp_cat["name"].sum()*100


fig, ax = plt.subplots(figsize = (15,15))
ax.bar(cmp_cat.index, cmp_cat["name"], color="C0")
ax2 = ax.twinx()
ax2.plot(cmp_cat.index, cmp_cat["cumpercentage"], color="C3", marker="D", ms=7)
ax2.yaxis.set_major_formatter(PercentFormatter())

ax.tick_params(axis="y", colors="C0")
ax2.tick_params(axis="y", colors="C3")
ax.tick_params(axis="x", rotation = 90, size = 22)
plt.show()

# %%
#type of offense code where there is shootings
shtgs = crime[crime.SHOOTING == 1]


sns.catplot(y='OFFENSE_CODE_GROUP',
           kind='count',
            height=8, 
            aspect=1.5,
            order=shtgs.OFFENSE_CODE_GROUP.value_counts().index,
           data=shtgs)

# %%
fig = plt.figure(figsize=(27,18)) # create a figure object
# Create the first subfigure

#plot 1
sub1 = fig.add_subplot(3,4,1)
sub1.set_xlabel('Lat')
sub1.set_title('Motor Vehicle Accident Response')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP == 'Motor Vehicle Accident Response'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)


#plot2
sub1 = fig.add_subplot(3,4,2)
sub1.set_xlabel('Lat')
sub1.set_title('Larceny')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Larceny'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

#plot3
sub1 = fig.add_subplot(3,4,3)
sub1.set_xlabel('Lat')
sub1.set_title('Medical Assistance')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Medical Assistance'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

#plot4
sub1 = fig.add_subplot(3,4,4)
sub1.set_xlabel('Lat')
sub1.set_title('Investigate Person')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Investigate Person'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

#plot 5
sub1 = fig.add_subplot(3,4,5)
sub1.set_xlabel('Lat')
sub1.set_title('Other')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Other'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

#plot 6
sub1 = fig.add_subplot(3,4,6)
sub1.set_xlabel('Lat')
sub1.set_title('Simple Assault')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Simple Assault'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)


#plot 7
sub1 = fig.add_subplot(3,4,7)
sub1.set_xlabel('Lat')
sub1.set_title('Drug Violation')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Drug Violation'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

#plot 8
sub1 = fig.add_subplot(3,4,8)
sub1.set_xlabel('Lat')
sub1.set_title('Vandalism')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Vandalism'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

#plot 9
sub1 = fig.add_subplot(3,4,9)
sub1.set_xlabel('Lat')
sub1.set_title('Verbal Disputes')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Verbal Disputes'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

#plot 10
sub1 = fig.add_subplot(3,4,10)
sub1.set_xlabel('Lat')
sub1.set_title('Investigate Property')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Verbal Disputes'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

#plot 11
sub1 = fig.add_subplot(3,4,11)
sub1.set_xlabel('Lat')
sub1.set_title('Towed')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Verbal Disputes'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

#plot 12
sub1 = fig.add_subplot(3,4,12)
sub1.set_xlabel('Lat')
sub1.set_title('Larceny From Motor Vehicle')
sns.scatterplot(x='Lat',y='Long', data=crime[crime.OFFENSE_CODE_GROUP =='Verbal Disputes'], alpha=0.01)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
crime.OFFENSE_CODE_GROUP.value_counts().head(12).index
# Out:
# Index(['Motor Vehicle Accident Response', 'Larceny', 'Medical Assistance',
#        'Investigate Person', 'Other', 'Simple Assault', 'Drug Violation',
#        'Vandalism', 'Verbal Disputes', 'Investigate Property', 'Towed',
#        'Larceny From Motor Vehicle'],
#       dtype='object')

# %%
#Finding areas where there is more than 7 crime incidents based on media
tmp = crime.groupby('INCIDENT_NUMBER')['YEAR'].count().sort_values(ascending = False)
tmp = pd.DataFrame({'INCIDENT_NUMBER': tmp.index, 'NUM_RECORDS': tmp.values})
seriousCrimes = crime.merge(tmp[tmp['NUM_RECORDS'] > 7], on = 'INCIDENT_NUMBER', how = 'inner')
seriousCrimes = seriousCrimes[['OFFENSE_CODE_GROUP','Lat','Long','NUM_RECORDS','STREET']].drop_duplicates()

# %% [markdown]
# # HD & JunW action item = Need to Plot a nice Median Curve for Crime Incident as well

# %%
seriousCrimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 278 entries, 0 to 585
# Data columns (total 5 columns):
# OFFENSE_CODE_GROUP    278 non-null object
# Lat                   278 non-null float64
# Long                  278 non-null float64
# NUM_RECORDS           278 non-null int64
# STREET                269 non-null object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 13.0+ KB

# %%
# Used this tutorial: https://medium.com/@bobhaffner/folium-markerclusters-and-fastmarkerclusters-1e03b01cb7b1
boston = folium.Map(location = [seriousCrimes['Lat'].mean(), 
                                  seriousCrimes['Long'].mean()], 
                      zoom_start = 12)
mc = MarkerCluster()
#creating a Marker for each point. 
for row in seriousCrimes.itertuples():
    mc.add_child(folium.Marker(location = [row.Lat, row.Long]))
boston.add_child(mc)

boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
shtng.head()
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 874       I192077645           413  Aggravated Assault
# 875       I192077645          2662          Ballistics
# 887       I192077627           413  Aggravated Assault
# 2783      I192075578           413  Aggravated Assault
# 3406      I192074923           413  Aggravated Assault
#
#                  OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  YEAR  \
# 874   ASSAULT - AGGRAVATED - BATTERY       B2            295        1  2019
# 875        BALLISTICS EVIDENCE/FOUND       B2            295        1  2019
# 887   ASSAULT - AGGRAVATED - BATTERY      C11            344        1  2019
# 2783  ASSAULT - AGGRAVATED - BATTERY       B3            457        1  2019
# 3406  ASSAULT - AGGRAVATED - BATTERY       B2            326        1  2019
#
#       MONTH DAY_OF_WEEK  HOUR  UCR_PART         STREET        Lat       Long  \
# 874       9    Thursday     2  Part One      DABNEY ST  42.324098 -71.084830
# ...

# %%
###shooting data
shtng = crime[(crime.SHOOTING == 1) & (crime.DISTRICT.notnull())]

boston1 = folium.Map(location = [shtng['Lat'].mean(), 
                                  shtng['Long'].mean()], 
                      zoom_start = 12)
mc = MarkerCluster()
#creating a Marker for each point. 
for row in shtng.itertuples():
    mc.add_child(folium.Marker(location = [row.Lat,  row.Long]))

boston1.add_child(mc)

boston1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
